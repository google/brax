# %%
# Essential imports for velocity-constrained ant training
from datetime import datetime
import functools
import time
import os
import subprocess

import jax
import numpy as np
import jax.numpy as jnp
from matplotlib import pyplot as plt
import wandb
import mujoco

from brax import envs
from brax.base import State as PipelineState
from brax.envs.base import Env, PipelineEnv, State as BraxState
from brax.training.agents.ppo_lagrange_v2 import train as ppo_lagrange_v2
from brax.training.agents.ppo import train as ppo
from brax.io import model as brax_model
from brax.io import json as brax_json

# GPU and MuJoCo validation
try:
    if subprocess.run('nvidia-smi', capture_output=True).returncode:
        print("Warning: Cannot communicate with GPU")
    else:
        print("✓ GPU detected")
except:
    print("Warning: nvidia-smi not available")

# Configure MuJoCo to use the EGL rendering backend (requires GPU)
os.environ['MUJOCO_GL'] = 'egl'

try:
    print('Checking MuJoCo installation...')
    mujoco.MjModel.from_xml_string('<mujoco/>')
    print('✓ MuJoCo installation successful')
except Exception as e:
    raise RuntimeError(f'MuJoCo installation failed: {e}')

# Tell XLA to use Triton GEMM, this improves steps/sec by ~30% on some GPUs
xla_flags = os.environ.get('XLA_FLAGS', '')
xla_flags += ' --xla_gpu_triton_gemm_any=True'
os.environ['XLA_FLAGS'] = xla_flags

print("✓ Environment setup complete")
# Out:
# ✓ GPU detected
# Checking MuJoCo installation...
# ✓ MuJoCo installation successful
# ✓ Environment setup complete

# %%
# No wrapper needed - environment now handles cost properly
# The ant_velocity_constrained environment directly maintains cost in state.info

# Args class for cleaner configuration management
class Args:
    def __init__(self, **kwargs):
        for key, value in kwargs.items():
            setattr(self, key, value)

# Environment configuration
env_name = 'ant_velocity_constrained'

# Environment specific parameters
env_config = {
    'max_velocity': 0.5 ,  # Maximum allowed velocity (m/s) - set below ant's natural max (~0.81 m/s)
    'velocity_cost_weight': 1.0,  # Weight for velocity violation cost
    'ctrl_cost_weight': 0.5,
}

# Training configuration using Args class
args = Args(
    num_timesteps=10_000_000,
    num_evals=10,
    episode_length=1000,
    num_envs=2048,
    batch_size=512,
    learning_rate=3e-4,
    entropy_cost=1e-3,
    unroll_length=10,
    num_minibatches=32,
    num_updates_per_batch=8,
    discounting=0.99,
    normalize_observations=True,
    reward_scaling=1.0,
    action_repeat=1,
    seed=42,
    max_devices_per_host=None,
    # PPO Lagrange specific
    safety_bound=0.1,  # Maximum allowed velocity violation
    lagrangian_coef_rate=0.01,
    initial_lambda_lagr=0.0,
    # Training metrics logging
    log_training_metrics=True,
    training_metrics_steps=None,  # Will be set based on episode_length * num_envs / 5
)

# Calculate training metrics steps
if args.training_metrics_steps is None:
    args.training_metrics_steps = args.episode_length * args.num_envs // 5

# Weights & Biases configuration
config_dict_for_wandb = vars(args)
config_dict_for_wandb.update({
    "environment_name": env_name,
    "max_velocity": env_config['max_velocity'],
    "velocity_cost_weight": env_config['velocity_cost_weight'],
    "ctrl_cost_weight": env_config['ctrl_cost_weight'],
})

run_name = f"{env_name}_ppo_lag_v2_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
wandb_config = {
    'project': 'velocity_constrained_ant',
    'name': run_name,
    'config': config_dict_for_wandb,
}

print(f"✓ Configuration loaded:")
print(f"  Environment: {env_name}")
print(f"  Max velocity: {env_config['max_velocity']} m/s")
print(f"  Safety bound: {args.safety_bound}")
print(f"  Training steps: {args.num_timesteps:,}")
print(f"  W&B project: {wandb_config['project']}")
print(f"  W&B run: {wandb_config['name']}")
# Out:
# ✓ Configuration loaded:
#   Environment: ant_velocity_constrained
#   Max velocity: 0.5 m/s
#   Safety bound: 0.1
#   Training steps: 10,000,000
#   W&B project: velocity_constrained_ant
#   W&B run: ant_velocity_constrained_ppo_lag_v2_20250720_124122

# %%
# Create training and evaluation environments
print("Creating environments...")

# Create environments directly - no wrapper needed
# The ant_velocity_constrained environment now handles cost properly in state.info
train_env = envs.get_environment(env_name, **env_config)
eval_env = envs.get_environment(env_name, **env_config)

print(f"✓ Environment '{env_name}' created:")
print(f"  Max velocity: {env_config['max_velocity']} m/s")
print(f"  Action space: {train_env.action_size}")
print(f"  Observation space: {train_env.observation_size}")
print(f"  Cost handling: Built-in to environment (state.info['cost'])")
# Out:
# Creating environments...
# /home/mrdbstn/school/safe-brax/safe-brax/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# ✓ Environment 'ant_velocity_constrained' created:
#   Max velocity: 0.5 m/s
#   Action space: 8
#   Observation space: 27
#   Cost handling: Built-in to environment (state.info['cost'])

# %%
# Enhanced training progress function inspired by mourad_lag.ipynb
training_metrics = []

def custom_progress_fn(num_steps, metrics, metrics_list=None, use_wandb=True):
    """
    Enhanced progress function to print metrics and log to Weights & Biases.
    Metrics dict can come from Brax's EpisodeMetricsLogger (keys like 'episode/reward')
    or from Evaluator (keys like 'eval/episode_reward').
    """
    print(f"Step {num_steps:,}:")
    wandb_log_data = {}
    
    # Key performance metrics
    perf_metrics = [
        'eval/episode_reward', 'eval/episode_forward_reward', 
        'episode/reward', 'episode/forward_reward'
    ]
    for key in perf_metrics:
        if key in metrics:
            value = metrics[key].item() if hasattr(metrics[key], 'item') else metrics[key]
            print(f"  {key.replace('eval/', '').replace('episode/', '')}: {value:.2f}")
    
    # Safety constraint metrics - print these prominently
    constraint_metrics = [
        'eval/episode_cost', 'eval/episode_velocity_cost', 'episode/cost',
        'training/lambda_lagr', 'training/cost_violation', 'training/mean_cost',
        'eval/episode_velocity_magnitude', 'eval/episode_velocity_violation'
    ]
    for key in constraint_metrics:
        if key in metrics:
            value = metrics[key].item() if hasattr(metrics[key], 'item') else metrics[key]
            if "lambda" in key or "cost" in key or "constraint" in key or "velocity" in key:
                if "lambda" in key:
                    print(f"  {key}: {value:.6f}")
                elif "velocity_magnitude" in key:
                    print(f"  {key}: {value:.2f} m/s")
                else:
                    print(f"  {key}: {value:.4f}")
    
    # Process all metrics for W&B logging
    for key, value in metrics.items():
        log_value = value.item() if hasattr(value, 'item') else value
        
        # Categorize metrics for better organization in W&B
        if not (key.startswith("episode/") or key.startswith("eval/") or key.startswith("training/")):
            wandb_log_data[f"training_batch/{key}"] = log_value
        else:
            wandb_log_data[key] = log_value

    # Log to W&B
    if use_wandb and wandb.run is not None and wandb_log_data:
        wandb.log(wandb_log_data, step=int(num_steps))

    # Store metrics locally for plotting
    if metrics_list is not None:
        metrics_data_local = {'step': num_steps}
        metrics_data_local.update(metrics)
        metrics_list.append(metrics_data_local)
    
    print()  # Empty line for readability

# Bound progress function for training
bound_progress_fn = functools.partial(
    custom_progress_fn, 
    metrics_list=training_metrics, 
    use_wandb=True
)

print("✓ Enhanced progress callback configured with W&B logging")
print("✓ Environment directly provides cost in state.info - no wrapper needed")
# Out:
# ✓ Enhanced progress callback configured with W&B logging
# ✓ Environment directly provides cost in state.info - no wrapper needed

# %%
# Initialize Weights & Biases
print("Initializing Weights & Biases...")
wandb_run = wandb.init(
    project=wandb_config['project'],
    name=wandb_config['name'],
    config=wandb_config['config'],
    reinit=True
)
print(f"✓ W&B run initialized: {wandb_run.name}")

# Configure and start training
print("Starting PPO Lagrange v2 training...")
start_time = time.time()

# Setup the PPO training function using Args class
train_fn = functools.partial(
    ppo_lagrange_v2,
    num_timesteps=args.num_timesteps,
    num_evals=args.num_evals,
    reward_scaling=args.reward_scaling,
    episode_length=args.episode_length,
    normalize_observations=args.normalize_observations,
    action_repeat=args.action_repeat,
    unroll_length=args.unroll_length,
    num_minibatches=args.num_minibatches,
    num_updates_per_batch=args.num_updates_per_batch,
    learning_rate=args.learning_rate,
    entropy_cost=args.entropy_cost,
    discounting=args.discounting,
    num_envs=args.num_envs,
    batch_size=args.batch_size,
    max_devices_per_host=args.max_devices_per_host,
    seed=args.seed,
    # Enable Brax's internal episode metrics logging
    log_training_metrics=args.log_training_metrics,
    training_metrics_steps=args.training_metrics_steps,
    # PPO-Lagrange specific parameters
    safety_bound=args.safety_bound,
    lagrangian_coef_rate=args.lagrangian_coef_rate,
    initial_lambda_lagr=args.initial_lambda_lagr,
)

print("✓ Training function configured with enhanced parameters")

# Train the model
make_inference_fn, params, final_metrics = train_fn(
    environment=train_env,
    eval_env=eval_env,
    progress_fn=bound_progress_fn
)

training_time = time.time() - start_time
print(f"✓ Training completed in {training_time:.1f} seconds")
print(f"Final metrics: {final_metrics}")

# Log final metrics to W&B
if final_metrics and wandb.run is not None:
    final_wandb_metrics = {}
    for key, value in final_metrics.items():
        if isinstance(value, (int, float, np.number)):
            final_wandb_metrics[f"final/{key}"] = float(value)
    
    # Add training summary
    final_wandb_metrics.update({
        'final/training_time_seconds': training_time,
        'final/training_steps': args.num_timesteps,
        'final/max_velocity_limit': env_config['max_velocity'],
        'final/safety_bound': args.safety_bound,
        'final/lagrangian_coef_rate': args.lagrangian_coef_rate,
    })
    
    wandb.log(final_wandb_metrics, step=args.num_timesteps)
    print("✓ Final metrics logged to W&B")
# Out:
# Initializing Weights & Biases...
# wandb: Currently logged in as: m-boustani (m-boustani-eindhoven-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/home/mrdbstn/school/safe-brax/safe-brax/notebooks/wandb/run-20250720_124148-4fhnexv3</code>
# Syncing run <strong><a href='https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant/runs/4fhnexv3' target="_blank">ant_velocity_constrained_ppo_lag_v2_20250720_124122</a></strong> to <a href='https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant' target="_blank">https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant</a>
#  View run at <a href='https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant/runs/4fhnexv3' target="_blank">https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant/runs/4fhnexv3</a>
# ✓ W&B run initialized: ant_velocity_constrained_ppo_lag_v2_20250720_124122
# Starting PPO Lagrange v2 training...
# ✓ Training function configured with enhanced parameters
# Step 0:
#   episode_reward: -14.56
#   episode_forward_reward: -2.17
#   eval/episode_cost: 16.9841
#   eval/episode_velocity_cost: 16.9841
#   eval/episode_velocity_magnitude: 33.24 m/s
#   eval/episode_velocity_violation: 16.9841
#
# Step 491,520:
#   forward_reward: 5.56
#   episode/cost: 21.4388
#
# Step 983,040:
#   forward_reward: 15.48
#   episode/cost: 24.3440
#
# Step 1,146,880:
#   episode_reward: 22.59
#   episode_forward_reward: 21.63
#   eval/episode_cost: 28.7630
#   eval/episode_velocity_cost: 28.7630
#   training/lambda_lagr: 0.017934
#   training/cost_violation: 0.4574
#   training/mean_cost: 0.5574
#   eval/episode_velocity_magnitude: 50.32 m/s
#   eval/episode_velocity_violation: 28.7630
#
# Step 1,474,560:
#   forward_reward: 17.63
#   episode/cost: 26.1478
#
# Step 1,966,080:
#   forward_reward: 39.74
#   episode/cost: 43.9808
#
# Step 2,293,760:
#   episode_reward: 66.13
#   episode_forward_reward: 52.79
#   eval/episode_cost: 50.9245
#   eval/episode_velocity_cost: 50.9245
#   training/lambda_lagr: 0.054055
#   training/cost_violation: 0.5729
#   training/mean_cost: 0.6729
#   eval/episode_velocity_magnitude: 82.55 m/s
#   eval/episode_velocity_violation: 50.9245
#
# Step 2,457,600:
#   forward_reward: 45.49
#   episode/cost: 43.7400
#
# Step 2,949,120:
#   forward_reward: 81.16
#   episode/cost: 74.9331
#
# Step 3,440,640:
#   forward_reward: 146.37
#   episode/cost: 124.4625
#
# Step 3,440,640:
#   episode_reward: 245.26
#   episode_forward_reward: 189.25
#   eval/episode_cost: 154.0473
#   eval/episode_velocity_cost: 154.0473
#   training/lambda_lagr: 0.100029
#   training/cost_violation: 0.7142
#   training/mean_cost: 0.8142
#   eval/episode_velocity_magnitude: 237.40 m/s
#   eval/episode_velocity_violation: 154.0473
#
# Step 3,932,160:
#   forward_reward: 203.34
#   episode/cost: 166.5682
#
# Step 4,423,680:
#   forward_reward: 358.80
#   episode/cost: 280.3602
#
# Step 4,587,520:
#   episode_reward: 925.31
#   episode_forward_reward: 734.13
#   eval/episode_cost: 562.9783
#   eval/episode_velocity_cost: 562.9783
#   training/lambda_lagr: 0.156158
#   training/cost_violation: 0.8875
#   training/mean_cost: 0.9875
#   eval/episode_velocity_magnitude: 799.52 m/s
#   eval/episode_velocity_violation: 562.9783
#
# Step 4,915,200:
#   forward_reward: 547.37
#   episode/cost: 422.5317
#
# Step 5,406,720:
#   forward_reward: 859.08
#   episode/cost: 671.3027
#
# Step 5,734,400:
#   episode_reward: 1681.59
#   episode_forward_reward: 1372.53
#   eval/episode_cost: 1101.2561
#   eval/episode_velocity_cost: 1101.2561
#   training/lambda_lagr: 0.232564
#   training/cost_violation: 1.2758
#   training/mean_cost: 1.3758
#   eval/episode_velocity_magnitude: 1437.40 m/s
#   eval/episode_velocity_violation: 1101.2561
#
# Step 5,898,240:
#   forward_reward: 1202.00
#   episode/cost: 938.0640
#
# Step 6,389,760:
#   forward_reward: 1278.50
#   episode/cost: 1019.8256
#
# Step 6,881,280:
#   forward_reward: 1552.86
#   episode/cost: 1255.1052
#
# Step 6,881,280:
#   episode_reward: 2171.66
#   episode_forward_reward: 1830.84
#   eval/episode_cost: 1533.5312
#   eval/episode_velocity_cost: 1533.5312
#   training/lambda_lagr: 0.340810
#   training/cost_violation: 1.7475
#   training/mean_cost: 1.8475
#   eval/episode_velocity_magnitude: 1888.03 m/s
#   eval/episode_velocity_violation: 1533.5312
#
# Step 7,372,800:
#   forward_reward: 1770.35
#   episode/cost: 1457.3573
#
# Step 7,864,320:
#   forward_reward: 2034.83
#   episode/cost: 1698.1282
#
# Step 8,028,160:
#   episode_reward: 3475.52
#   episode_forward_reward: 3023.36
#   eval/episode_cost: 2627.4917
#   eval/episode_velocity_cost: 2627.4917
#   training/lambda_lagr: 0.484807
#   training/cost_violation: 2.3336
#   training/mean_cost: 2.4336
#   eval/episode_velocity_magnitude: 3077.45 m/s
#   eval/episode_velocity_violation: 2627.4917
#
# Step 8,355,840:
#   forward_reward: 2338.71
#   episode/cost: 1987.4617
#
# Step 8,847,360:
#   forward_reward: 2774.75
#   episode/cost: 2395.3339
#
# Step 9,175,040:
#   episode_reward: 4477.63
#   episode_forward_reward: 3997.53
#   eval/episode_cost: 3562.7944
#   eval/episode_velocity_cost: 3562.7944
#   training/lambda_lagr: 0.681965
#   training/cost_violation: 3.2034
#   training/mean_cost: 3.3034
#   eval/episode_velocity_magnitude: 4029.56 m/s
#   eval/episode_velocity_violation: 3562.7944
#
# Step 9,338,880:
#   forward_reward: 3290.93
#   episode/cost: 2877.3780
#
# Step 9,830,400:
#   forward_reward: 3711.94
#   episode/cost: 3276.7580
#
# Step 10,321,920:
#   forward_reward: 4075.54
#   episode/cost: 3623.5319
#
# Step 10,321,920:
#   episode_reward: 4901.20
#   episode_forward_reward: 4318.06
#   eval/episode_cost: 3853.0894
#   eval/episode_velocity_cost: 3853.0894
#   training/lambda_lagr: 0.934475
#   training/cost_violation: 3.8039
#   training/mean_cost: 3.9039
#   eval/episode_velocity_magnitude: 4341.69 m/s
#   eval/episode_velocity_violation: 3853.0894
#
# ✓ Training completed in 328.7 seconds
# Final metrics: {'eval/walltime': 98.69923233985901, 'training/sps': np.float64(57005.93067559605), 'training/walltime': 215.81825757026672, 'training/cost_v_loss': Array(19.772959, dtype=float32), 'training/cost_violation': Array(3.8038545, dtype=float32), 'training/entropy_loss': Array(0.00396539, dtype=float32), 'training/lambda_lagr': Array(0.9344751, dtype=float32), 'training/mean_cost': Array(3.9038546, dtype=float32), 'training/policy_loss': Array(-0.0057224, dtype=float32), 'training/total_loss': Array(47.020046, dtype=float32), 'training/v_loss': Array(27.24885, dtype=float32), 'eval/episode_cost': Array(3853.0894, dtype=float32), 'eval/episode_distance_from_origin': Array(105299.29, dtype=float32), 'eval/episode_forward_reward': Array(4318.0615, dtype=float32), 'eval/episode_reward': Array(4901.1963, dtype=float32), 'eval/episode_reward_contact': Array(0., dtype=float32), 'eval/episode_reward_ctrl': Array(-395.01987, dtype=float32), 'eval/episode_reward_forward': Array(4318.0615, dtype=float32), 'eval/episode_reward_survive': Array(978.1719, dtype=float32), 'eval/episode_velocity_cost': Array(3853.0894, dtype=float32), 'eval/episode_velocity_magnitude': Array(4341.688, dtype=float32), 'eval/episode_velocity_violation': Array(3853.0894, dtype=float32), 'eval/episode_x_position': Array(105235., dtype=float32), 'eval/episode_x_velocity': Array(4318.0615, dtype=float32), 'eval/episode_y_position': Array(2681.0835, dtype=float32), 'eval/episode_y_velocity': Array(94.70201, dtype=float32), 'eval/episode_cost_std': Array(488.925, dtype=float32), 'eval/episode_distance_from_origin_std': Array(17001.473, dtype=float32), 'eval/episode_forward_reward_std': Array(545.5964, dtype=float32), 'eval/episode_reward_std': Array(614.0111, dtype=float32), 'eval/episode_reward_contact_std': Array(0., dtype=float32), 'eval/episode_reward_ctrl_std': Array(47.43579, dtype=float32), 'eval/episode_reward_forward_std': Array(545.5964, dtype=float32), 'eval/episode_reward_survive_std': Array(117.171425, dtype=float32), 'eval/episode_velocity_cost_std': Array(488.925, dtype=float32), 'eval/episode_velocity_magnitude_std': Array(546.21454, dtype=float32), 'eval/episode_velocity_violation_std': Array(488.925, dtype=float32), 'eval/episode_x_position_std': Array(16995.355, dtype=float32), 'eval/episode_x_velocity_std': Array(545.5964, dtype=float32), 'eval/episode_y_position_std': Array(1595.7987, dtype=float32), 'eval/episode_y_velocity_std': Array(56.0328, dtype=float32), 'eval/avg_episode_length': Array(978.1719, dtype=float32), 'eval/std_episode_length': Array(117.171425, dtype=float32), 'eval/epoch_eval_time': 6.844396352767944, 'eval/sps': 18701.430104677598}
# ✓ Final metrics logged to W&B
# wandb: WARNING Tried to log to step 10000000 that is less than the current step 10321920. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.

# %%
# Save trained model
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
model_dir = 'models'
os.makedirs(model_dir, exist_ok=True)

model_path = f'{model_dir}/ant_velocity_constrained_{timestamp}'
brax_model.save_params(model_path, params)
print(f"Model saved to: {model_path}")
# Out:
# Model saved to: models/ant_velocity_constrained_20250720_124718

# %%
# Evaluation rollout
print("Running evaluation rollout...")

rollout_env = envs.get_environment(env_name, **env_config)
rollout_steps = 2000

# Create inference function
inference_fn = make_inference_fn(params)
jit_inference_fn = jax.jit(inference_fn)
jit_reset = jax.jit(rollout_env.reset)
jit_step = jax.jit(rollout_env.step)

# Initialize rollout
rng = jax.random.PRNGKey(0)
state = jit_reset(rng)

# Collect rollout data
rollout_data = {
    'rewards': [],
    'costs': [],
    'velocities': [],
    'velocity_violations': [],
    'x_positions': [],
    'y_positions': [],
    'forward_rewards': [],
}

trajectory_states = []

for step in range(rollout_steps):
    # Get action from policy
    rng, act_rng = jax.random.split(rng)
    action, _ = jit_inference_fn(state.obs, act_rng)
    
    # Step environment
    state = jit_step(state, action)
    trajectory_states.append(state.pipeline_state)
    
    # Collect metrics
    rollout_data['rewards'].append(float(state.reward))
    rollout_data['costs'].append(float(state.metrics.get('cost', 0)))
    rollout_data['velocities'].append(float(state.metrics.get('velocity_magnitude', 0)))
    rollout_data['velocity_violations'].append(float(state.metrics.get('velocity_violation', 0)))
    rollout_data['x_positions'].append(float(state.metrics.get('x_position', 0)))
    rollout_data['y_positions'].append(float(state.metrics.get('y_position', 0)))
    rollout_data['forward_rewards'].append(float(state.metrics.get('forward_reward', 0)))
    
    if step % 500 == 0:
        print(f"Rollout step {step}/{rollout_steps}")
    
    if state.done:
        print(f"Episode terminated at step {step}")
        break

print(f"Rollout completed with {len(rollout_data['rewards'])} steps")

# Summary statistics
total_reward = sum(rollout_data['rewards'])
total_cost = sum(rollout_data['costs'])
max_velocity = max(rollout_data['velocities'])
avg_velocity = np.mean(rollout_data['velocities'])
total_violations = sum(rollout_data['velocity_violations'])

print(f"\nRollout Summary:")
print(f"  Total reward: {total_reward:.2f}")
print(f"  Total cost: {total_cost:.3f}")
print(f"  Max velocity: {max_velocity:.2f} m/s (limit: {env_config['max_velocity']} m/s)")
print(f"  Average velocity: {avg_velocity:.2f} m/s")
print(f"  Total velocity violations: {total_violations:.3f}")
# Out:
# Running evaluation rollout...
# /home/mrdbstn/school/safe-brax/safe-brax/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Rollout step 0/2000
# Rollout step 500/2000
# Rollout step 1000/2000
# Rollout step 1500/2000
# Rollout completed with 2000 steps
#
# Rollout Summary:
#   Total reward: 10098.39
#   Total cost: 7925.516
#   Max velocity: 6.78 m/s (limit: 0.5 m/s)
#   Average velocity: 4.46 m/s
#   Total velocity violations: 7925.516

# %%
# Save trajectory
trajectory_dir = 'trajectories'
os.makedirs(trajectory_dir, exist_ok=True)

trajectory_path = f'{trajectory_dir}/ant_velocity_constrained_rollout_{timestamp}.json'
brax_json.save(trajectory_path, rollout_env.sys, trajectory_states)
print(f"Trajectory saved to: {trajectory_path}")
# Out:
# Trajectory saved to: trajectories/ant_velocity_constrained_rollout_20250720_124718.json

# %%
# Generate plots
plt.style.use('default')
plot_dir = 'plots'
os.makedirs(plot_dir, exist_ok=True)

# Training progress plots
if training_metrics:
    steps = [m['step'] for m in training_metrics if 'eval/episode_reward' in m]
    rewards = [m['eval/episode_reward'] for m in training_metrics if 'eval/episode_reward' in m]
    costs = [m.get('eval/episode_cost', 0) for m in training_metrics if 'eval/episode_reward' in m]
    lambdas = [m.get('training/lambda_lagr', 0) for m in training_metrics if 'training/lambda_lagr' in m]
    
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    # Reward progress
    ax1.plot(steps, rewards, 'b-', linewidth=2)
    ax1.set_xlabel('Training Steps')
    ax1.set_ylabel('Episode Reward')
    ax1.set_title('Training Reward Progress')
    ax1.grid(True, alpha=0.3)
    
    # Cost progress
    ax2.plot(steps, costs, 'r-', linewidth=2)
    ax2.axhline(y=args.safety_bound, color='r', linestyle='--', alpha=0.7, label='Safety Bound')
    ax2.set_xlabel('Training Steps')
    ax2.set_ylabel('Episode Cost')
    ax2.set_title('Constraint Violation Progress')
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    # Lambda evolution
    if lambdas:
        lambda_steps = [m['step'] for m in training_metrics if 'training/lambda_lagr' in m]
        ax3.plot(lambda_steps, lambdas, 'g-', linewidth=2)
        ax3.set_xlabel('Training Steps')
        ax3.set_ylabel('Lambda (Lagrange Multiplier)')
        ax3.set_title('Lagrange Multiplier Evolution')
        ax3.grid(True, alpha=0.3)
    
    # Velocity during rollout
    rollout_steps_plot = range(len(rollout_data['velocities']))
    ax4.plot(rollout_steps_plot, rollout_data['velocities'], 'purple', linewidth=1, alpha=0.8)
    ax4.axhline(y=env_config['max_velocity'], color='r', linestyle='--', alpha=0.7, label=f'Max Velocity ({env_config["max_velocity"]} m/s)')
    ax4.set_xlabel('Rollout Steps')
    ax4.set_ylabel('Velocity Magnitude (m/s)')
    ax4.set_title('Velocity During Evaluation Rollout')
    ax4.legend()
    ax4.grid(True, alpha=0.3)
    
    plt.tight_layout()
    training_plot_path = f'{plot_dir}/ant_velocity_constrained_training_{timestamp}.png'
    plt.savefig(training_plot_path, dpi=150, bbox_inches='tight')
    plt.show()
    print(f"Training plots saved to: {training_plot_path}")

# Rollout analysis plots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
steps_rollout = range(len(rollout_data['rewards']))

# Rewards over time
ax1.plot(steps_rollout, rollout_data['rewards'], 'b-', alpha=0.7)
ax1.set_xlabel('Steps')
ax1.set_ylabel('Reward')
ax1.set_title('Rewards During Rollout')
ax1.grid(True, alpha=0.3)

# Costs over time
ax2.plot(steps_rollout, rollout_data['costs'], 'r-', alpha=0.7)
ax2.set_xlabel('Steps')
ax2.set_ylabel('Cost (Velocity Violation)')
ax2.set_title('Constraint Violations During Rollout')
ax2.grid(True, alpha=0.3)

# Trajectory (X-Y position)
ax3.plot(rollout_data['x_positions'], rollout_data['y_positions'], 'g-', alpha=0.8)
ax3.scatter(rollout_data['x_positions'][0], rollout_data['y_positions'][0], c='green', s=100, label='Start', zorder=5)
ax3.scatter(rollout_data['x_positions'][-1], rollout_data['y_positions'][-1], c='red', s=100, label='End', zorder=5)
ax3.set_xlabel('X Position (m)')
ax3.set_ylabel('Y Position (m)')
ax3.set_title('Ant Trajectory')
ax3.legend()
ax3.grid(True, alpha=0.3)
ax3.axis('equal')

# Velocity magnitude vs violations
ax4.plot(steps_rollout, rollout_data['velocities'], 'purple', label='Velocity Magnitude', linewidth=2)
ax4.axhline(y=env_config['max_velocity'], color='r', linestyle='--', alpha=0.7, label=f'Velocity Limit ({env_config["max_velocity"]} m/s)')
ax4_twin = ax4.twinx()
ax4_twin.plot(steps_rollout, rollout_data['velocity_violations'], 'orange', alpha=0.6, label='Velocity Violations')
ax4.set_xlabel('Steps')
ax4.set_ylabel('Velocity (m/s)', color='purple')
ax4_twin.set_ylabel('Violations', color='orange')
ax4.set_title('Velocity Tracking and Violations')
ax4.legend(loc='upper left')
ax4_twin.legend(loc='upper right')
ax4.grid(True, alpha=0.3)

plt.tight_layout()
rollout_plot_path = f'{plot_dir}/ant_velocity_constrained_rollout_{timestamp}.png'
plt.savefig(rollout_plot_path, dpi=150, bbox_inches='tight')
plt.show()
print(f"Rollout plots saved to: {rollout_plot_path}")
# Out:
# Training plots saved to: plots/ant_velocity_constrained_training_20250720_124718.png
# Rollout plots saved to: plots/ant_velocity_constrained_rollout_20250720_124718.png

# %%
# Final summary
print("\n" + "="*60)
print("VELOCITY-CONSTRAINED ANT TRAINING SUMMARY")
print("="*60)
print(f"Environment: {env_name}")
print(f"Training steps: {args.num_timesteps:,}")
print(f"Training time: {training_time:.1f} seconds")
print(f"Velocity constraint: {env_config['max_velocity']} m/s")
print(f"Safety bound: {args.safety_bound}")
print(f"Lagrangian coef rate: {args.lagrangian_coef_rate}")
if 'wandb_run' in locals() and wandb_run is not None:
    print(f"W&B project: {wandb_config['project']}")
    print(f"W&B run: {wandb_run.name}")
    print(f"W&B url: {wandb_run.url}")
print()
print("FINAL PERFORMANCE:")
if final_metrics:
    for key, value in final_metrics.items():
        if isinstance(value, (int, float, np.number)):
            log_value = value.item() if hasattr(value, 'item') else value
            print(f"  {key}: {log_value:.4f}")
print()
print("ROLLOUT ANALYSIS:")
print(f"  Total reward: {total_reward:.2f}")
print(f"  Total cost: {total_cost:.3f}")
print(f"  Max velocity: {max_velocity:.2f} m/s (limit: {env_config['max_velocity']} m/s)")
print(f"  Average velocity: {avg_velocity:.2f} m/s")
print(f"  Constraint violations: {total_violations:.3f}")
print(f"  Distance traveled: {rollout_data['x_positions'][-1]:.2f} m")
print(f"  Steps completed: {len(rollout_data['rewards'])}")
print()
print("FILES & ARTIFACTS:")
print(f"  Model: {model_path}")
print(f"  Trajectory: {trajectory_path}")
if 'training_plot_path' in locals():
    print(f"  Training plots: {training_plot_path}")
if 'rollout_plot_path' in locals():
    print(f"  Rollout plots: {rollout_plot_path}")
print()
print("TRAINING CONFIGURATION:")
print(f"  Cost handling: Built-in to environment (no wrapper needed)")
print(f"  PPO Lagrange v2: Enhanced with training metrics logging")
print(f"  Episodes logged: {args.training_metrics_steps} steps interval")
print(f"  Environment: Direct cost in state.info for PPO Lagrange v2")
print("="*60)
# Out:
# ============================================================
# VELOCITY-CONSTRAINED ANT TRAINING SUMMARY
# ============================================================
# Environment: ant_velocity_constrained
# Training steps: 10,000,000
# Training time: 328.7 seconds
# Velocity constraint: 0.5 m/s
# Safety bound: 0.1
# Lagrangian coef rate: 0.01
# W&B project: velocity_constrained_ant
# W&B run: ant_velocity_constrained_ppo_lag_v2_20250720_124122
# W&B url: https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant/runs/4fhnexv3
#
# FINAL PERFORMANCE:
#   eval/walltime: 98.6992
#   training/sps: 57005.9307
#   training/walltime: 215.8183
#   eval/epoch_eval_time: 6.8444
#   eval/sps: 18701.4301
#
# ROLLOUT ANALYSIS:
#   Total reward: 10098.39
#   Total cost: 7925.516
#   Max velocity: 6.78 m/s (limit: 0.5 m/s)
#   Average velocity: 4.46 m/s
#   Constraint violations: 7925.516
#   Distance traveled: 444.30 m
#   Steps completed: 2000
#
# FILES & ARTIFACTS:
#   Model: models/ant_velocity_constrained_20250720_124718
#   Trajectory: trajectories/ant_velocity_constrained_rollout_20250720_124718.json
#   Training plots: plots/ant_velocity_constrained_training_20250720_124718.png
#   Rollout plots: plots/ant_velocity_constrained_rollout_20250720_124718.png
#
# TRAINING CONFIGURATION:
#   Cost handling: Built-in to environment (no wrapper needed)
#   PPO Lagrange v2: Enhanced with training metrics logging
#   Episodes logged: 409600 steps interval
#   Environment: Direct cost in state.info for PPO Lagrange v2
# ============================================================

# %%
# Finish W&B run
if wandb.run is not None:
    # Log rollout summary to W&B
    rollout_summary = {
        'rollout/total_reward': total_reward,
        'rollout/total_cost': total_cost,
        'rollout/max_velocity': max_velocity,
        'rollout/avg_velocity': avg_velocity,
        'rollout/total_violations': total_violations,
        'rollout/distance_traveled': rollout_data['x_positions'][-1],
        'rollout/steps_completed': len(rollout_data['rewards']),
    }
    wandb.log(rollout_summary, step=args.num_timesteps)
    
    # Upload plots to W&B
    if 'training_plot_path' in locals():
        wandb.log({"training_plots": wandb.Image(training_plot_path)})
    if 'rollout_plot_path' in locals():
        wandb.log({"rollout_plots": wandb.Image(rollout_plot_path)})
    
    print("Rollout metrics and plots uploaded to W&B")
    wandb.finish()
    print("W&B run finished")
# Out:
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# Rollout metrics and plots uploaded to W&B
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>episode/cost</td><td>▁▁▁▁▁▁▁▁▂▂▂▃▃▃▄▄▅▆▇▇█</td></tr><tr><td>episode/distance_from_origin</td><td>▁▁▁▁▁▁▁▁▁▂▂▃▃▃▄▄▅▅▆▇█</td></tr><tr><td>episode/forward_reward</td><td>▁▁▁▁▁▁▁▁▂▂▂▃▃▄▄▄▅▆▇▇█</td></tr><tr><td>episode/length</td><td>▁▁▁▁▁▁▂▂▃▄▅▆▆▆▆▇▇▇███</td></tr><tr><td>episode/reward_contact</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode/reward_ctrl</td><td>█████▇▇▇▆▅▃▂▃▂▂▂▂▂▁▁▁</td></tr><tr><td>episode/reward_forward</td><td>▁▁▁▁▁▁▁▁▂▂▂▃▃▄▄▄▅▆▇▇█</td></tr><tr><td>episode/reward_survive</td><td>▁▁▁▁▁▁▂▂▃▄▅▆▆▆▆▇▇▇███</td></tr><tr><td>episode/sum_reward</td><td>▁▁▁▁▁▁▁▁▂▂▃▃▃▄▄▅▅▆▇▇█</td></tr><tr><td>episode/velocity_cost</td><td>▁▁▁▁▁▁▁▁▂▂▂▃▃▃▄▄▅▆▇▇█</td></tr><tr><td>episode/velocity_magnitude</td><td>▁▁▁▁▁▁▁▁▂▂▃▃▃▄▄▅▅▆▇▇█</td></tr><tr><td>episode/velocity_violation</td><td>▁▁▁▁▁▁▁▁▂▂▂▃▃▃▄▄▅▆▇▇█</td></tr><tr><td>episode/x_position</td><td>▁▁▁▁▁▁▁▁▁▂▂▃▃▃▄▄▅▅▆▇█</td></tr><tr><td>episode/x_velocity</td><td>▁▁▁▁▁▁▁▁▂▂▂▃▃▄▄▄▅▆▇▇█</td></tr><tr><td>episode/y_position</td><td>▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▃▄▆██</td></tr><tr><td>episode/y_velocity</td><td>▃▃▃▃▃▃▂▂▂▂▂▁▂▁▁▂▄▆▇█▇</td></tr><tr><td>eval/avg_episode_length</td><td>▁▁▁▂▄▆▆▇██</td></tr><tr><td>eval/episode_cost</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_cost_std</td><td>▁▁▁▂▄▆█▇▇▅</td></tr><tr><td>eval/episode_distance_from_origin</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_distance_from_origin_std</td><td>▁▁▁▂▅▆█▇█▅</td></tr><tr><td>eval/episode_forward_reward</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_forward_reward_std</td><td>▁▁▁▂▅▆█▇▇▅</td></tr><tr><td>eval/episode_reward</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_reward_contact</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/episode_reward_contact_std</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/episode_reward_ctrl</td><td>███▇▄▃▂▁▁▂</td></tr><tr><td>eval/episode_reward_ctrl_std</td><td>▁▁▁▃█▇█▅▃▂</td></tr><tr><td>eval/episode_reward_forward</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_reward_forward_std</td><td>▁▁▁▂▅▆█▇▇▅</td></tr><tr><td>eval/episode_reward_std</td><td>▁▁▁▂▅▆█▇▇▅</td></tr><tr><td>eval/episode_reward_survive</td><td>▁▁▁▂▄▆▆▇██</td></tr><tr><td>eval/episode_reward_survive_std</td><td>▁▁▂▃▇██▅▄▃</td></tr><tr><td>eval/episode_velocity_cost</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_velocity_cost_std</td><td>▁▁▁▂▄▆█▇▇▅</td></tr><tr><td>eval/episode_velocity_magnitude</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_velocity_magnitude_std</td><td>▁▁▁▂▅▆█▇▇▅</td></tr><tr><td>eval/episode_velocity_violation</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_velocity_violation_std</td><td>▁▁▁▂▄▆█▇▇▅</td></tr><tr><td>eval/episode_x_position</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_x_position_std</td><td>▁▁▁▂▅▆█▇█▅</td></tr><tr><td>eval/episode_x_velocity</td><td>▁▁▁▁▂▃▄▆▇█</td></tr><tr><td>eval/episode_x_velocity_std</td><td>▁▁▁▂▅▆█▇▇▅</td></tr><tr><td>eval/episode_y_position</td><td>▂▂▂▂▂▁▁█▇▆</td></tr><tr><td>eval/episode_y_position_std</td><td>▁▁▁▂▄▆▆█▇▅</td></tr><tr><td>eval/episode_y_velocity</td><td>▃▃▃▂▂▁▁█▇▅</td></tr><tr><td>eval/episode_y_velocity_std</td><td>▁▁▂▄▆▆▆█▇▅</td></tr><tr><td>eval/epoch_eval_time</td><td>█▇▁▁▁▁▁▁▂▁</td></tr><tr><td>eval/sps</td><td>▁▁██▇█▇█▆▇</td></tr><tr><td>eval/std_episode_length</td><td>▁▁▂▃▇██▅▄▃</td></tr><tr><td>eval/walltime</td><td>▁▃▄▄▅▅▆▇▇█</td></tr><tr><td>training/cost_v_loss</td><td>▁▂▃▄▄▆██▄</td></tr><tr><td>training/cost_violation</td><td>▁▁▂▂▃▄▅▇█</td></tr><tr><td>training/entropy_loss</td><td>▁▂▃▄▅▅▆▇█</td></tr><tr> ...
#  View run <strong style="color:#cdcd00">ant_velocity_constrained_ppo_lag_v2_20250720_124122</strong> at: <a href='https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant/runs/4fhnexv3' target="_blank">https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant/runs/4fhnexv3</a><br> View project at: <a href='https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant' target="_blank">https://wandb.ai/m-boustani-eindhoven-university-of-technology/velocity_constrained_ant</a><br>Synced 5 W&B file(s), 2 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250720_124148-4fhnexv3/logs</code>
# Tried to log to step 10000000 that is less than the current step 10321920. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# W&B run finished
